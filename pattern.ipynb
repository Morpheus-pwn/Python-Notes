# %%
for i in range(5):
    print("*" * i)
# Out:
# *
# **
# ***
# ****

# %%
for i in range(5):
    for j in range(i):
        print(j+1,end="")
    print(i+1)

# 1
# 12
# 123
# 1234
# 12345
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
# 1
# 22
# 333
# 4444
# 55555

for i in range(6):
    for j in range(i):
        print(i,end="")
    print("")
# Out:
# 1
# 22
# 333
# 4444
# 55555

# %%
for i in range(5):
    for j in range(5):
        print("*",end=" ")
    print("*")
# Out:
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
